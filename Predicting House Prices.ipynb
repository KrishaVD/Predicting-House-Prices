# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\krish\OneDrive\KrishDocs\A a-level preparation\datasets\train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (1460, 81)

# %%
data['LotFrontage']=data["LotFrontage"].fillna(data["LotFrontage"].mean())
data['MasVnrArea']=data['MasVnrArea'].fillna(data['MasVnrArea'].mean())

# %%
data['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
corrmat = data.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[top_corr_features].corr(), annot=True)

# %%
data.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.360472 -0.135924     0.048774    -0.095344
# LotFrontage     -0.360472     1.000000  0.299770     0.227640    -0.043057
# LotArea         -0.135924     0.299770  1.000000     0.089887    -0.002313
# OverallQual      0.048774     0.227640  0.089887     1.000000    -0.164442
# OverallCond     -0.095344    -0.043057 -0.002313    -0.164442     1.000000
# YearBuilt        0.055247     0.102822 -0.006359     0.572248    -0.416547
# YearRemodAdd     0.037597     0.078159  0.000370     0.550929     0.033111
# MasVnrArea       0.030653     0.176067  0.096506     0.399918    -0.140926
# BsmtFinSF1      -0.070131     0.219694  0.210663     0.201128    -0.064679
# BsmtFinSF2      -0.080261     0.040881  0.109626    -0.084262     0.035724
# BsmtUnfSF       -0.144114     0.106613 -0.012679     0.293100    -0.161540
# ...

# %%
data.drop(['Alley'], axis=1, inplace=True)

# %%
data.drop(['PoolQC', 'Fence', 'MiscFeature','GarageYrBlt','Id'], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
data['BsmtQual']=data['BsmtQual'].fillna(data['BsmtQual'].mode()[0])
data['BsmtQual'].isnull().sum()
# Out:
# 0

# %%
data['BsmtCond']=data['BsmtCond'].fillna(data['BsmtCond'].mode()[0])
data['GarageFinish']=data['GarageFinish'].fillna(data['GarageFinish'].mode()[0])
data['GarageQual']=data['GarageQual'].fillna(data['GarageQual'].mode()[0])
data['GarageCond']=data['GarageCond'].fillna(data['GarageCond'].mode()[0])
data['MasVnrType']=data['MasVnrType'].fillna(data['MasVnrType'].mode()[0])

# %%
data.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
data['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %% [markdown]
#  BsmtExposure-mode
# BsmtFinType2-mode
# Fireplaces- mean
# FireplaceQu - mode

# %%
data['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
data['BsmtExposure']=data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0])
data['BsmtQual']=data['BsmtQual'].fillna(data['BsmtQual'].mode()[0])
data['FireplaceQu']=data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0])
data['BsmtFinType2']=data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0])
data['GarageFinish']=data['GarageFinish'].fillna(data['GarageFinish'].mode()[0])

# %%
data['BsmtExposure'].isnull().sum()
# Out:
# 0

# %%
data["Fireplaces"]=data["Fireplaces"].fillna(data["Fireplaces"].mean())

# %%
data["Fireplaces"].isnull().sum()
# Out:
# 0

# %%
sns.heatmap(data.isnull(),yticklabels=False, cbar=False, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
data.dropna(inplace=True)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Finally no more null vales (the data is clean!!)

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
df1=pd.get_dummies(data = data, prefix = 'OHE', prefix_sep='_')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1348 entries, 0 to 1459
# Columns: 270 entries, MSSubClass to OHE_Partial
# dtypes: float64(2), int64(34), uint8(234)
# memory usage: 697.7 KB

# %%
from sklearn.model_selection import train_test_split
X=df1.drop('SalePrice', axis=1)
y=df1['SalePrice']
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.25, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([223189.95544973, 127664.98775757, 125840.55375708, 237601.4509359 ,
#        159867.21762029, 239341.75948825, 106104.4850245 , 111629.38598239,
#        117262.20735569, 194554.69146088, 147760.0379565 , 202201.09462674,
#         77249.61964647, 174040.41744293, 195354.12970551,  87020.84562829,
#        185987.05966042, 197085.04162644, 104102.28998751, 317866.97250456,
#        345171.6745513 , 365567.55793508, 229019.44514667, 157008.69384946,
#        120930.2387873 , 199336.55639353, 198095.33185879, 103675.63664033,
#        152753.11788388, 160213.02453445, 151758.89478672, 232054.03690234,
#        172034.41294133, 326618.52518894, 200806.10745458, 128229.29399351,
#        210618.25374323,  96905.38905158,  97962.97668598, 211869.79330929,
#        105896.60731085, 206133.9306661 , 114412.73309484, 140802.921562  ,
#         96831.07936477, 214324.62194212, 344295.5921041 ,  33385.56994052,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7924873541309173

# %%
reg.coef_
# Out:
# array([-5.18780000e+01,  5.75967385e+01,  8.13304187e-01,  5.52524455e+03,
#         7.68948105e+03,  4.30517547e+02,  1.07325613e+01,  1.03974614e+01,
#         1.76317254e+01,  3.74416734e+00, -6.04016965e-01,  2.07718661e+01,
#         2.73628961e+01,  3.62902560e+01, -2.64243203e+01,  3.72288326e+01,
#         9.72346934e+02,  2.64792002e+03,  4.83045445e+03,  2.56363427e+03,
#        -3.17107026e+03, -2.14341290e+04, -6.18235094e+02,  1.74107130e+03,
#         3.20501231e+03,  1.47377473e+01,  1.60622490e+01,  1.46440202e+01,
#        -9.23646902e+00,  2.33815830e+01,  2.03847050e+01,  7.91217453e+01,
#         3.00056020e-01, -1.73225245e+02,  1.12636472e+02, -2.93402709e+04,
#         1.50805791e+04,  6.20186289e+03,  6.31001268e+03,  1.74781623e+03,
#        -1.72900169e+04,  1.72900169e+04, -1.75874079e+03,  3.49087115e+03,
#        -1.24859772e+03, -4.83532647e+02,  4.30636325e+03,  7.73507812e+03,
# ...

# %%
reg.intercept_
# Out:
# -1362541.8359276822

# %%
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(121)
sns.scatterplot(x=y_test,y=y_pred,ax=ax,color='b')
ax.set(xlabel="Test data", ylabel="Predicted Data")
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')
# Out:
# Text(0.5, 1.0, 'Check for Linearity:\n Actual Vs Predicted value')
